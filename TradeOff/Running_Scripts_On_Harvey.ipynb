# %% [markdown]
# # How to run your code on the Pawar lab's High Performance Computer, Harvey. This notebook will go through using both sbatch and screens to remotely run the scripts.

# %% [markdown]
# ## 1. Using screens
# Need to figure out why you would use screens and not just sbatch. Screen is a terminal multiplexer, which allows a user to access multiple separate terminal sessions inside a single terminal window or remote terminal session. More info: [https://help.ubuntu.com/community/Screen](https://help.ubuntu.com/community/Screen)

# %% [markdown]
# To open a new screen:

# %% [raw]
# screen -S <name_of_session>

# %% [markdown]
# ### Once creating a screen you can run your scripts like you would normally on your computer (Given that you have transferred all the files necessary onto Harvey). For example:

# %% [raw]
# cd correct/directory # locate the right directory
# julia script.jl  # run the julia script

# %% [markdown]
# ### Once you have run the script it is very important to detach from the screen before exiting. Otherwise the screen won't continue to run on Harvey by itself.
#
# #### To detach and exit from the screen:
# ctrl A then ctrl D
#
# #### To delete a screen:
# Once in the screen, ctrl A and ctrl D to detach first.
# Then ctrl A then ctrl C
#
# ### Here are some useful commands to manage your screens:

# %% [raw]
# # To open (reattach) to an existing screen
# screen -r <name_of_session>
#
# # To kill a screen
# screen -XS <name_of_session>
#
# # To see all existing screens
# screen -ls

# %% [markdown]
# # 2. Using sbatch
# blah blah blah
